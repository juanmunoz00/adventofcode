# %%
filepath = 'C:/'
filename = 'input_d10.txt'
complete_filepathname = filepath+filename
print('Opening from '+complete_filepathname)

def yet_another_position_shift():
    #sec=1#starting from 1st position change
    for sec in range(1,10):
        with open(complete_filepathname) as f:
            for line in f:
                print(line)
                #get position
                #bestMincommachar=strbestMin.find(',')
                posX1=line.find('=<')+2    
                pos1=line[posX1:posY]
                posX2=line.find(',')

                posX=line[posX1:posX2]
                print('Initial position X: '+posX.strip())

                #print(pos.strip())
                posY2=line.find('>')
                posY1=line[posX2+2:posY2]
                print('Initial position Y: '+posY1.strip())

                #get velocity
                mov=line.find('v')+10
                eol=len(line)-2
                line2=line[mov:eol]

                intmovX=line2.find(',')

                movX=line2[0:intmovX]
                print('Velocity X: '+movX)

                movY=line2[intmovX+1:eol]
                print('Velocity Y: '+movY)

                #New coordinates due change in position
                #sec*vx+posx

                newCoordx=sec*int(posX)+int(movX)
                newCoordy=sec*int(posY1)+int(movY)
                print('New coordinates due change in position after '+str(sec)+' seconds: <'+str(newCoordx)+','+str(newCoordy)+'>')

#sec += 1
        
yet_another_position_shift()
# Out:
# Opening from C:/input_d10.txt
# position=<-53868, -10684> velocity=< 5,  1>
#
# Initial position X: -53868
# Initial position Y: -10684
# Velocity X:  5
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-53863,-10683>
# position=<-43043, -43128> velocity=< 4,  4>
#
# Initial position X: -43043
# Initial position Y: -43128
# Velocity X:  4
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-43039,-43124>
# position=< 11010,  54188> velocity=<-1, -5>
#
# Initial position X: 11010
# Initial position Y: 54188
# Velocity X: -1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <11009,54183>
# position=< 43453,  10942> velocity=<-4, -1>
#
# Initial position X: 43453
# Initial position Y: 10942
# Velocity X: -4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <43449,10941>
# position=< 54258,  10941> velocity=<-5, -1>
#
# Initial position X: 54258
# Initial position Y: 10941
# Velocity X: -5
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <54253,10940>
# position=<-53835,  32566> velocity=< 5, -3>
#
# Initial position X: -53835
# Initial position Y: 32566
# Velocity X:  5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-53830,32563>
# position=< 43437,  54191> velocity=<-4, -5>
#
# Initial position X: 43437
# Initial position Y: 54191
# Velocity X: -4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <43433,54186>
# position=< 43445,  21753> velocity=<-4, -2>
#
# Initial position X: 43445
# Initial position Y: 21753
# Velocity X: -4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <43441,21751>
# position=< 21829, -53942> velocity=<-2,  5>
#
# Initial position X: 21829
# Initial position Y: -53942
# Velocity X: -2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <21827,-53937>
# position=< 54258,  32570> velocity=<-5, -3>
#
# Initial position X: 54258
# Initial position Y: 32570
# Velocity X: -5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <54253,32567>
# position=< 32624, -21499> velocity=<-3,  2>
#
# Initial position X: 32624
# Initial position Y: -21499
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32621,-21497>
# position=< 32648,  43384> velocity=<-3, -4>
#
# Initial position X: 32648
# Initial position Y: 43384
# Velocity X: -3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <32645,43380>
# position=<-32249,  32571> velocity=< 3, -3>
#
# Initial position X: -32249
# Initial position Y: 32571
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32246,32568>
# position=<-10596, -32307> velocity=< 1,  3>
#
# Initial position X: -10596
# Initial position Y: -32307
# Velocity X:  1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-10595,-32304>
# position=< 54250, -10690> velocity=<-5,  1>
#
# Initial position X: 54250
# Initial position Y: -10690
# Velocity X: -5
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <54245,-10689>
# position=<-10628,  21757> velocity=< 1, -2>
#
# Initial position X: -10628
# Initial position Y: 21757
# Velocity X:  1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-10627,21755>
# position=< 32624,  21754> velocity=<-3, -2>
#
# Initial position X: 32624
# Initial position Y: 21754
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32621,21752>
# position=< 54251, -21494> velocity=<-5,  2>
#
# Initial position X: 54251
# Initial position Y: -21494
# Velocity X: -5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <54246,-21492>
# position=<-21399,  21754> velocity=< 2, -2>
#
# Initial position X: -21399
# Initial position Y: 21754
# Velocity X:  2
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-21397,21752>
# position=<-43048,  10936> velocity=< 4, -1>
#
# Initial position X: -43048
# Initial position Y: 10936
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43044,10935>
# position=<-10567, -21494> velocity=< 1,  2>
#
# Initial position X: -10567
# Initial position Y: -21494
# Velocity X:  1
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-10566,-21492>
# position=<-53848, -21500> velocity=< 5,  2>
#
# Initial position X: -53848
# Initial position Y: -21500
# Velocity X:  5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-53843,-21498>
# position=< 21843,  10937> velocity=<-2, -1>
#
# Initial position X: 21843
# Initial position Y: 10937
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21841,10936>
# position=<-32202, -10683> velocity=< 3,  1>
#
# Initial position X: -32202
# Initial position Y: -10683
# Velocity X:  3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-32199,-10682>
# position=<-43035,  10945> velocity=< 4, -1>
#
# Initial position X: -43035
# Initial position Y: 10945
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43031,10944>
# position=< 43445, -53938> velocity=<-4,  5>
#
# Initial position X: 43445
# Initial position Y: -53938
# Velocity X: -4
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <43441,-53933>
# position=< 32653, -32307> velocity=<-3,  3>
#
# Initial position X: 32653
# Initial position Y: -32307
# Velocity X: -3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <32650,-32304>
# position=<-10600, -10683> velocity=< 1,  1>
#
# Initial position X: -10600
# Initial position Y: -10683
# Velocity X:  1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-10599,-10682>
# position=<-32198, -21498> velocity=< 3,  2>
#
# Initial position X: -32198
# Initial position Y: -21498
# Velocity X:  3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-32195,-21496>
# position=< 32656,  43378> velocity=<-3, -4>
#
# Initial position X: 32656
# Initial position Y: 43378
# Velocity X: -3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <32653,43374>
# position=< 43488,  21749> velocity=<-4, -2>
#
# Initial position X: 43488
# Initial position Y: 21749
# Velocity X: -4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <43484,21747>
# position=< 11038, -53939> velocity=<-1,  5>
#
# Initial position X: 11038
# Initial position Y: -53939
# Velocity X: -1
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <11037,-53934>
# position=<-53824, -32307> velocity=< 5,  3>
#
# Initial position X: -53824
# Initial position Y: -32307
# Velocity X:  5
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-53819,-32304>
# position=< 54278,  43377> velocity=<-5, -4>
#
# Initial position X: 54278
# Initial position Y: 43377
# Velocity X: -5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <54273,43373>
# position=<-32241,  43383> velocity=< 3, -4>
#
# Initial position X: -32241
# Initial position Y: 43383
# Velocity X:  3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-32238,43379>
# position=<-32198, -53941> velocity=< 3,  5>
#
# Initial position X: -32198
# Initial position Y: -53941
# Velocity X:  3
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-32195,-53936>
# position=<-32252,  21749> velocity=< 3, -2>
#
# Initial position X: -32252
# Initial position Y: 21749
# Velocity X:  3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-32249,21747>
# position=<-43011, -53938> velocity=< 4,  5>
#
# Initial position X: -43011
# Initial position Y: -53938
# Velocity X:  4
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-43007,-53933>
# position=<-21399,  54193> velocity=< 2, -5>
#
# Initial position X: -21399
# Initial position Y: 54193
# Velocity X:  2
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-21397,54188>
# position=<-10623,  32571> velocity=< 1, -3>
#
# Initial position X: -10623
# Initial position Y: 32571
# Velocity X:  1
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-10622,32568>
# position=<-43030,  21758> velocity=< 4, -2>
#
# Initial position X: -43030
# Initial position Y: 21758
# Velocity X:  4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-43026,21756>
# position=< 54290,  32566> velocity=<-5, -3>
#
# Initial position X: 54290
# Initial position Y: 32566
# Velocity X: -5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <54285,32563>
# position=<-32252,  10945> velocity=< 3, -1>
#
# Initial position X: -32252
# Initial position Y: 10945
# Velocity X:  3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-32249,10944>
# position=< 32624, -43121> velocity=<-3,  4>
#
# Initial position X: 32624
# Initial position Y: -43121
# Velocity X: -3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <32621,-43117>
# position=<-43062,  32562> velocity=< 4, -3>
#
# Initial position X: -43062
# Initial position Y: 32562
# Velocity X:  4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-43058,32559>
# position=< 21824, -32307> velocity=<-2,  3>
#
# Initial position X: 21824
# Initial position Y: -32307
# Velocity X: -2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <21822,-32304>
# position=< 21813,  32566> velocity=<-2, -3>
#
# Initial position X: 21813
# Initial position Y: 32566
# Velocity X: -2
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <21811,32563>
# position=<-32211,  32562> velocity=< 3, -3>
#
# Initial position X: -32211
# Initial position Y: 32562
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32208,32559>
# position=< 21840, -43128> velocity=<-2,  4>
#
# Initial position X: 21840
# Initial position Y: -43128
# Velocity X: -2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <21838,-43124>
# position=<-21429, -21499> velocity=< 2,  2>
#
# Initial position X: -21429
# Initial position Y: -21499
# Velocity X:  2
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-21427,-21497>
# position=<-53879,  21758> velocity=< 5, -2>
#
# Initial position X: -53879
# Initial position Y: 21758
# Velocity X:  5
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-53874,21756>
# position=< 43448,  21753> velocity=<-4, -2>
#
# Initial position X: 43448
# Initial position Y: 21753
# Velocity X: -4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <43444,21751>
# position=< 21827, -43127> velocity=<-2,  4>
#
# Initial position X: 21827
# Initial position Y: -43127
# Velocity X: -2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <21825,-43123>
# position=< 32664, -21501> velocity=<-3,  2>
#
# Initial position X: 32664
# Initial position Y: -21501
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32661,-21499>
# position=< 11026,  32564> velocity=<-1, -3>
#
# Initial position X: 11026
# Initial position Y: 32564
# Velocity X: -1
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <11025,32561>
# position=<-21417, -10682> velocity=< 2,  1>
#
# Initial position X: -21417
# Initial position Y: -10682
# Velocity X:  2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-21415,-10681>
# position=<-43067,  32569> velocity=< 4, -3>
#
# Initial position X: -43067
# Initial position Y: 32569
# Velocity X:  4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-43063,32566>
# position=<-21409,  10939> velocity=< 2, -1>
#
# Initial position X: -21409
# Initial position Y: 10939
# Velocity X:  2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-21407,10938>
# position=<-32222, -10686> velocity=< 3,  1>
#
# Initial position X: -32222
# Initial position Y: -10686
# Velocity X:  3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-32219,-10685>
# position=< 43447, -21499> velocity=<-4,  2>
#
# Initial position X: 43447
# Initial position Y: -21499
# Velocity X: -4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <43443,-21497>
# position=<-10611,  21758> velocity=< 1, -2>
#
# Initial position X: -10611
# Initial position Y: 21758
# Velocity X:  1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-10610,21756>
# position=<-21413, -10687> velocity=< 2,  1>
#
# Initial position X: -21413
# Initial position Y: -10687
# Velocity X:  2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-21411,-10686>
# position=<-10576,  54190> velocity=< 1, -5>
#
# Initial position X: -10576
# Initial position Y: 54190
# Velocity X:  1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-10575,54185>
# position=<-53822,  54197> velocity=< 5, -5>
#
# Initial position X: -53822
# Initial position Y: 54197
# Velocity X:  5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-53817,54192>
# position=< 11050,  54191> velocity=<-1, -5>
#
# Initial position X: 11050
# Initial position Y: 54191
# Velocity X: -1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <11049,54186>
# position=< 32677,  21749> velocity=<-3, -2>
#
# Initial position X: 32677
# Initial position Y: 21749
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32674,21747>
# position=< 43445,  32569> velocity=<-4, -3>
#
# Initial position X: 43445
# Initial position Y: 32569
# Velocity X: -4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <43441,32566>
# position=<-43039,  32565> velocity=< 4, -3>
#
# Initial position X: -43039
# Initial position Y: 32565
# Velocity X:  4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-43035,32562>
# position=<-32202,  32567> velocity=< 3, -3>
#
# Initial position X: -32202
# Initial position Y: 32567
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32199,32564>
# position=< 32624, -32307> velocity=<-3,  3>
#
# Initial position X: 32624
# Initial position Y: -32307
# Velocity X: -3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <32621,-32304>
# position=<-21433,  43376> velocity=< 2, -4>
#
# Initial position X: -21433
# Initial position Y: 43376
# Velocity X:  2
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-21431,43372>
# position=< 21829,  43384> velocity=<-2, -4>
#
# Initial position X: 21829
# Initial position Y: 43384
# Velocity X: -2
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <21827,43380>
# position=< 32637, -21502> velocity=<-3,  2>
#
# Initial position X: 32637
# Initial position Y: -21502
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32634,-21500>
# position=<-53824, -53940> velocity=< 5,  5>
#
# Initial position X: -53824
# Initial position Y: -53940
# Velocity X:  5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-53819,-53935>
# position=< 21867, -43129> velocity=<-2,  4>
#
# Initial position X: 21867
# Initial position Y: -43129
# Velocity X: -2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <21865,-43125>
# position=< 32669,  10941> velocity=<-3, -1>
#
# Initial position X: 32669
# Initial position Y: 10941
# Velocity X: -3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <32666,10940>
# position=< 11038, -53936> velocity=<-1,  5>
#
# Initial position X: 11038
# Initial position Y: -53936
# Velocity X: -1
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <11037,-53931>
# position=< 43463, -10685> velocity=<-4,  1>
#
# Initial position X: 43463
# Initial position Y: -10685
# Velocity X: -4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <43459,-10684>
# position=<-10576,  32570> velocity=< 1, -3>
#
# Initial position X: -10576
# Initial position Y: 32570
# Velocity X:  1
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-10575,32567>
# position=<-43016, -10690> velocity=< 4,  1>
#
# Initial position X: -43016
# Initial position Y: -10690
# Velocity X:  4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-43012,-10689>
# position=<-21422, -10681> velocity=< 2,  1>
#
# Initial position X: -21422
# Initial position Y: -10681
# Velocity X:  2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-21420,-10680>
# position=<-53843,  43384> velocity=< 5, -4>
#
# Initial position X: -53843
# Initial position Y: 43384
# Velocity X:  5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-53838,43380>
# position=< 32669,  32568> velocity=<-3, -3>
#
# Initial position X: 32669
# Initial position Y: 32568
# Velocity X: -3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <32666,32565>
# position=< 54301, -21503> velocity=<-5,  2>
#
# Initial position X: 54301
# Initial position Y: -21503
# Velocity X: -5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <54296,-21501>
# position=<-32206, -21495> velocity=< 3,  2>
#
# Initial position X: -32206
# Initial position Y: -21495
# Velocity X:  3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-32203,-21493>
# position=<-10603,  21752> velocity=< 1, -2>
#
# Initial position X: -10603
# Initial position Y: 21752
# Velocity X:  1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-10602,21750>
# position=<-53827, -21503> velocity=< 5,  2>
#
# Initial position X: -53827
# Initial position Y: -21503
# Velocity X:  5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-53822,-21501>
# position=< 10998,  10936> velocity=<-1, -1>
#
# Initial position X: 10998
# Initial position Y: 10936
# Velocity X: -1
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <10997,10935>
# position=<-43040,  10940> velocity=< 4, -1>
#
# Initial position X: -43040
# Initial position Y: 10940
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43036,10939>
# position=<-10583, -10683> velocity=< 1,  1>
#
# Initial position X: -10583
# Initial position Y: -10683
# Velocity X:  1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-10582,-10682>
# position=<-21440,  10940> velocity=< 2, -1>
#
# Initial position X: -21440
# Initial position Y: 10940
# Velocity X:  2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-21438,10939>
# position=< 11006,  43383> velocity=<-1, -4>
#
# Initial position X: 11006
# Initial position Y: 43383
# Velocity X: -1
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <11005,43379>
# position=< 54310, -43120> velocity=<-5,  4>
#
# Initial position X: 54310
# Initial position Y: -43120
# Velocity X: -5
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <54305,-43116>
# position=< 43465, -32310> velocity=<-4,  3>
#
# Initial position X: 43465
# Initial position Y: -32310
# Velocity X: -4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <43461,-32307>
# position=< 43437, -10684> velocity=<-4,  1>
#
# Initial position X: 43437
# Initial position Y: -10684
# Velocity X: -4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <43433,-10683>
# position=<-43035,  21749> velocity=< 4, -2>
#
# Initial position X: -43035
# Initial position Y: 21749
# Velocity X:  4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-43031,21747>
# position=<-32242,  32569> velocity=< 3, -3>
#
# Initial position X: -32242
# Initial position Y: 32569
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32239,32566>
# position=< 11017, -43129> velocity=<-1,  4>
#
# Initial position X: 11017
# Initial position Y: -43129
# Velocity X: -1
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <11016,-43125>
# position=< 11011, -10688> velocity=<-1,  1>
#
# Initial position X: 11011
# Initial position Y: -10688
# Velocity X: -1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <11010,-10687>
# position=<-10603, -43127> velocity=< 1,  4>
#
# Initial position X: -10603
# Initial position Y: -43127
# Velocity X:  1
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-10602,-43123>
# position=<-32238,  54193> velocity=< 3, -5>
#
# Initial position X: -32238
# Initial position Y: 54193
# Velocity X:  3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-32235,54188>
# position=<-43067, -10689> velocity=< 4,  1>
#
# Initial position X: -43067
# Initial position Y: -10689
# Velocity X:  4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-43063,-10688>
# position=< 54258,  21755> velocity=<-5, -2>
#
# Initial position X: 54258
# Initial position Y: 21755
# Velocity X: -5
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <54253,21753>
# position=<-21412,  43375> velocity=< 2, -4>
#
# Initial position X: -21412
# Initial position Y: 43375
# Velocity X:  2
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-21410,43371>
# position=<-53864,  54195> velocity=< 5, -5>
#
# Initial position X: -53864
# Initial position Y: 54195
# Velocity X:  5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-53859,54190>
# position=< 21870, -32307> velocity=<-2,  3>
#
# Initial position X: 21870
# Initial position Y: -32307
# Velocity X: -2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <21868,-32304>
# position=<-43030,  43384> velocity=< 4, -4>
#
# Initial position X: -43030
# Initial position Y: 43384
# Velocity X:  4
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-43026,43380>
# position=<-43011, -10689> velocity=< 4,  1>
#
# Initial position X: -43011
# Initial position Y: -10689
# Velocity X:  4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-43007,-10688>
# position=<-32214, -32309> velocity=< 3,  3>
#
# Initial position X: -32214
# Initial position Y: -32309
# Velocity X:  3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-32211,-32306>
# position=< 11040, -10690> velocity=<-1,  1>
#
# Initial position X: 11040
# Initial position Y: -10690
# Velocity X: -1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <11039,-10689>
# position=<-32209,  32564> velocity=< 3, -3>
#
# Initial position X: -32209
# Initial position Y: 32564
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32206,32561>
# position=< 21832,  10937> velocity=<-2, -1>
#
# Initial position X: 21832
# Initial position Y: 10937
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21830,10936>
# position=<-43058,  10940> velocity=< 4, -1>
#
# Initial position X: -43058
# Initial position Y: 10940
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43054,10939>
# position=< 54290, -32309> velocity=<-5,  3>
#
# Initial position X: 54290
# Initial position Y: -32309
# Velocity X: -5
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <54285,-32306>
# position=< 21827,  21755> velocity=<-2, -2>
#
# Initial position X: 21827
# Initial position Y: 21755
# Velocity X: -2
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <21825,21753>
# position=<-43010,  10945> velocity=< 4, -1>
#
# Initial position X: -43010
# Initial position Y: 10945
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43006,10944>
# position=< 21811, -10688> velocity=<-2,  1>
#
# Initial position X: 21811
# Initial position Y: -10688
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21809,-10687>
# position=<-32225,  32570> velocity=< 3, -3>
#
# Initial position X: -32225
# Initial position Y: 32570
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32222,32567>
# position=<-21389, -43129> velocity=< 2,  4>
#
# Initial position X: -21389
# Initial position Y: -43129
# Velocity X:  2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-21387,-43125>
# position=<-10602, -21499> velocity=< 1,  2>
#
# Initial position X: -10602
# Initial position Y: -21499
# Velocity X:  1
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-10601,-21497>
# position=<-10569, -10681> velocity=< 1,  1>
#
# Initial position X: -10569
# Initial position Y: -10681
# Velocity X:  1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-10568,-10680>
# position=< 32626, -10690> velocity=<-3,  1>
#
# Initial position X: 32626
# Initial position Y: -10690
# Velocity X: -3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <32623,-10689>
# position=<-10619,  43379> velocity=< 1, -4>
#
# Initial position X: -10619
# Initial position Y: 43379
# Velocity X:  1
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-10618,43375>
# position=<-53872, -43129> velocity=< 5,  4>
#
# Initial position X: -53872
# Initial position Y: -43129
# Velocity X:  5
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-53867,-43125>
# position=<-53836, -21502> velocity=< 5,  2>
#
# Initial position X: -53836
# Initial position Y: -21502
# Velocity X:  5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-53831,-21500>
# position=< 11054, -32311> velocity=<-1,  3>
#
# Initial position X: 11054
# Initial position Y: -32311
# Velocity X: -1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <11053,-32308>
# position=<-21401,  54197> velocity=< 2, -5>
#
# Initial position X: -21401
# Initial position Y: 54197
# Velocity X:  2
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-21399,54192>
# position=< 32649,  54191> velocity=<-3, -5>
#
# Initial position X: 32649
# Initial position Y: 54191
# Velocity X: -3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <32646,54186>
# position=< 54279,  10937> velocity=<-5, -1>
#
# Initial position X: 54279
# Initial position Y: 10937
# Velocity X: -5
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <54274,10936>
# position=< 21822,  32562> velocity=<-2, -3>
#
# Initial position X: 21822
# Initial position Y: 32562
# Velocity X: -2
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <21820,32559>
# position=< 43449, -32312> velocity=<-4,  3>
#
# Initial position X: 43449
# Initial position Y: -32312
# Velocity X: -4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <43445,-32309>
# position=< 54295,  43383> velocity=<-5, -4>
#
# Initial position X: 54295
# Initial position Y: 43383
# Velocity X: -5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <54290,43379>
# position=< 21812, -21503> velocity=<-2,  2>
#
# Initial position X: 21812
# Initial position Y: -21503
# Velocity X: -2
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <21810,-21501>
# position=< 11050, -32308> velocity=<-1,  3>
#
# Initial position X: 11050
# Initial position Y: -32308
# Velocity X: -1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <11049,-32305>
# position=<-10620, -53938> velocity=< 1,  5>
#
# Initial position X: -10620
# Initial position Y: -53938
# Velocity X:  1
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-10619,-53933>
# position=< 11043, -21497> velocity=<-1,  2>
#
# Initial position X: 11043
# Initial position Y: -21497
# Velocity X: -1
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <11042,-21495>
# position=< 43482, -21498> velocity=<-4,  2>
#
# Initial position X: 43482
# Initial position Y: -21498
# Velocity X: -4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <43478,-21496>
# position=< 32652, -53936> velocity=<-3,  5>
#
# Initial position X: 32652
# Initial position Y: -53936
# Velocity X: -3
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <32649,-53931>
# position=<-32243,  21753> velocity=< 3, -2>
#
# Initial position X: -32243
# Initial position Y: 21753
# Velocity X:  3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-32240,21751>
# position=<-53824,  43378> velocity=< 5, -4>
#
# Initial position X: -53824
# Initial position Y: 43378
# Velocity X:  5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-53819,43374>
# position=<-53868, -21497> velocity=< 5,  2>
#
# Initial position X: -53868
# Initial position Y: -21497
# Velocity X:  5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-53863,-21495>
# position=< 21867,  10936> velocity=<-2, -1>
#
# Initial position X: 21867
# Initial position Y: 10936
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21865,10935>
# position=< 54255,  21749> velocity=<-5, -2>
#
# Initial position X: 54255
# Initial position Y: 21749
# Velocity X: -5
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <54250,21747>
# position=<-10612, -32308> velocity=< 1,  3>
#
# Initial position X: -10612
# Initial position Y: -32308
# Velocity X:  1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-10611,-32305>
# position=< 21828, -10690> velocity=<-2,  1>
#
# Initial position X: 21828
# Initial position Y: -10690
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21826,-10689>
# position=<-32235,  43384> velocity=< 3, -4>
#
# Initial position X: -32235
# Initial position Y: 43384
# Velocity X:  3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-32232,43380>
# position=< 21859,  10943> velocity=<-2, -1>
#
# Initial position X: 21859
# Initial position Y: 10943
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21857,10942>
# position=< 21840, -53942> velocity=<-2,  5>
#
# Initial position X: 21840
# Initial position Y: -53942
# Velocity X: -2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <21838,-53937>
# position=< 21843, -43123> velocity=<-2,  4>
#
# Initial position X: 21843
# Initial position Y: -43123
# Velocity X: -2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <21841,-43119>
# position=< 32632,  43381> velocity=<-3, -4>
#
# Initial position X: 32632
# Initial position Y: 43381
# Velocity X: -3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <32629,43377>
# position=< 32644,  10936> velocity=<-3, -1>
#
# Initial position X: 32644
# Initial position Y: 10936
# Velocity X: -3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <32641,10935>
# position=< 54282, -32308> velocity=<-5,  3>
#
# Initial position X: 54282
# Initial position Y: -32308
# Velocity X: -5
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <54277,-32305>
# position=< 43461, -43120> velocity=<-4,  4>
#
# Initial position X: 43461
# Initial position Y: -43120
# Velocity X: -4
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <43457,-43116>
# position=<-21409, -53940> velocity=< 2,  5>
#
# Initial position X: -21409
# Initial position Y: -53940
# Velocity X:  2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-21407,-53935>
# position=<-32237, -43120> velocity=< 3,  4>
#
# Initial position X: -32237
# Initial position Y: -43120
# Velocity X:  3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-32234,-43116>
# position=< 11050, -10684> velocity=<-1,  1>
#
# Initial position X: 11050
# Initial position Y: -10684
# Velocity X: -1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <11049,-10683>
# position=<-32251,  10940> velocity=< 3, -1>
#
# Initial position X: -32251
# Initial position Y: 10940
# Velocity X:  3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-32248,10939>
# position=< 21855, -21502> velocity=<-2,  2>
#
# Initial position X: 21855
# Initial position Y: -21502
# Velocity X: -2
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <21853,-21500>
# position=< 43493,  32570> velocity=<-4, -3>
#
# Initial position X: 43493
# Initial position Y: 32570
# Velocity X: -4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <43489,32567>
# position=< 21835, -10681> velocity=<-2,  1>
#
# Initial position X: 21835
# Initial position Y: -10681
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21833,-10680>
# position=< 11050,  10940> velocity=<-1, -1>
#
# Initial position X: 11050
# Initial position Y: 10940
# Velocity X: -1
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <11049,10939>
# position=< 32684,  32571> velocity=<-3, -3>
#
# Initial position X: 32684
# Initial position Y: 32571
# Velocity X: -3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <32681,32568>
# position=< 54275, -10687> velocity=<-5,  1>
#
# Initial position X: 54275
# Initial position Y: -10687
# Velocity X: -5
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <54270,-10686>
# position=< 32658, -21494> velocity=<-3,  2>
#
# Initial position X: 32658
# Initial position Y: -21494
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32655,-21492>
# position=< 11046,  21756> velocity=<-1, -2>
#
# Initial position X: 11046
# Initial position Y: 21756
# Velocity X: -1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <11045,21754>
# position=< 32676, -43121> velocity=<-3,  4>
#
# Initial position X: 32676
# Initial position Y: -43121
# Velocity X: -3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <32673,-43117>
# position=< 11043, -10686> velocity=<-1,  1>
#
# Initial position X: 11043
# Initial position Y: -10686
# Velocity X: -1
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <11042,-10685>
# position=<-53864, -10683> velocity=< 5,  1>
#
# Initial position X: -53864
# Initial position Y: -10683
# Velocity X:  5
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-53859,-10682>
# position=<-43059,  10945> velocity=< 4, -1>
#
# Initial position X: -43059
# Initial position Y: 10945
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43055,10944>
# position=<-43067,  43379> velocity=< 4, -4>
#
# Initial position X: -43067
# Initial position Y: 43379
# Velocity X:  4
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-43063,43375>
# position=<-21421,  54197> velocity=< 2, -5>
#
# Initial position X: -21421
# Initial position Y: 54197
# Velocity X:  2
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-21419,54192>
# position=<-43022,  54195> velocity=< 4, -5>
#
# Initial position X: -43022
# Initial position Y: 54195
# Velocity X:  4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-43018,54190>
# position=<-53830,  32571> velocity=< 5, -3>
#
# Initial position X: -53830
# Initial position Y: 32571
# Velocity X:  5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-53825,32568>
# position=<-43066, -53933> velocity=< 4,  5>
#
# Initial position X: -43066
# Initial position Y: -53933
# Velocity X:  4
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-43062,-53928>
# position=<-32214, -21494> velocity=< 3,  2>
#
# Initial position X: -32214
# Initial position Y: -21494
# Velocity X:  3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-32211,-21492>
# position=< 43449, -10686> velocity=<-4,  1>
#
# Initial position X: 43449
# Initial position Y: -10686
# Velocity X: -4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <43445,-10685>
# position=< 32665,  21754> velocity=<-3, -2>
#
# Initial position X: 32665
# Initial position Y: 21754
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32662,21752>
# position=< 54258,  32571> velocity=<-5, -3>
#
# Initial position X: 54258
# Initial position Y: 32571
# Velocity X: -5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <54253,32568>
# position=< 54302, -21496> velocity=<-5,  2>
#
# Initial position X: 54302
# Initial position Y: -21496
# Velocity X: -5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <54297,-21494>
# position=<-32202,  10938> velocity=< 3, -1>
#
# Initial position X: -32202
# Initial position Y: 10938
# Velocity X:  3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-32199,10937>
# position=<-43024,  21749> velocity=< 4, -2>
#
# Initial position X: -43024
# Initial position Y: 21749
# Velocity X:  4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <-43020,21747>
# position=<-53864,  54195> velocity=< 5, -5>
#
# Initial position X: -53864
# Initial position Y: 54195
# Velocity X:  5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-53859,54190>
# position=< 54252,  54197> velocity=<-5, -5>
#
# Initial position X: 54252
# Initial position Y: 54197
# Velocity X: -5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <54247,54192>
# position=<-43067, -43125> velocity=< 4,  4>
#
# Initial position X: -43067
# Initial position Y: -43125
# Velocity X:  4
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-43063,-43121>
# position=<-53872, -53933> velocity=< 5,  5>
#
# Initial position X: -53872
# Initial position Y: -53933
# Velocity X:  5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-53867,-53928>
# position=< 54263,  10938> velocity=<-5, -1>
#
# Initial position X: 54263
# Initial position Y: 10938
# Velocity X: -5
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <54258,10937>
# position=<-21413, -32309> velocity=< 2,  3>
#
# Initial position X: -21413
# Initial position Y: -32309
# Velocity X:  2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-21411,-32306>
# position=< 21840,  10944> velocity=<-2, -1>
#
# Initial position X: 21840
# Initial position Y: 10944
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21838,10943>
# position=< 21815, -10690> velocity=<-2,  1>
#
# Initial position X: 21815
# Initial position Y: -10690
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21813,-10689>
# position=<-43019,  32570> velocity=< 4, -3>
#
# Initial position X: -43019
# Initial position Y: 32570
# Velocity X:  4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-43015,32567>
# position=< 21867, -10688> velocity=<-2,  1>
#
# Initial position X: 21867
# Initial position Y: -10688
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21865,-10687>
# position=< 21839, -32310> velocity=<-2,  3>
#
# Initial position X: 21839
# Initial position Y: -32310
# Velocity X: -2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <21837,-32307>
# position=<-32214, -32312> velocity=< 3,  3>
#
# Initial position X: -32214
# Initial position Y: -32312
# Velocity X:  3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-32211,-32309>
# position=<-21420, -32308> velocity=< 2,  3>
#
# Initial position X: -21420
# Initial position Y: -32308
# Velocity X:  2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-21418,-32305>
# position=<-32251, -43129> velocity=< 3,  4>
#
# Initial position X: -32251
# Initial position Y: -43129
# Velocity X:  3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-32248,-43125>
# position=<-43058, -21503> velocity=< 4,  2>
#
# Initial position X: -43058
# Initial position Y: -21503
# Velocity X:  4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-43054,-21501>
# position=<-32241,  43377> velocity=< 3, -4>
#
# Initial position X: -32241
# Initial position Y: 43377
# Velocity X:  3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-32238,43373>
# position=< 32633, -10686> velocity=<-3,  1>
#
# Initial position X: 32633
# Initial position Y: -10686
# Velocity X: -3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <32630,-10685>
# position=<-43054, -32315> velocity=< 4,  3>
#
# Initial position X: -43054
# Initial position Y: -32315
# Velocity X:  4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-43050,-32312>
# position=< 32629,  21749> velocity=<-3, -2>
#
# Initial position X: 32629
# Initial position Y: 21749
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32626,21747>
# position=< 54306, -53935> velocity=<-5,  5>
#
# Initial position X: 54306
# Initial position Y: -53935
# Velocity X: -5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <54301,-53930>
# position=< 54263,  54191> velocity=<-5, -5>
#
# Initial position X: 54263
# Initial position Y: 54191
# Velocity X: -5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <54258,54186>
# position=<-43010, -43120> velocity=< 4,  4>
#
# Initial position X: -43010
# Initial position Y: -43120
# Velocity X:  4
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-43006,-43116>
# position=<-32222,  10936> velocity=< 3, -1>
#
# Initial position X: -32222
# Initial position Y: 10936
# Velocity X:  3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-32219,10935>
# position=<-21385,  10936> velocity=< 2, -1>
#
# Initial position X: -21385
# Initial position Y: 10936
# Velocity X:  2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-21383,10935>
# position=< 43437,  32570> velocity=<-4, -3>
#
# Initial position X: 43437
# Initial position Y: 32570
# Velocity X: -4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <43433,32567>
# position=< 32681,  32571> velocity=<-3, -3>
#
# Initial position X: 32681
# Initial position Y: 32571
# Velocity X: -3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <32678,32568>
# position=<-53835, -53934> velocity=< 5,  5>
#
# Initial position X: -53835
# Initial position Y: -53934
# Velocity X:  5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-53830,-53929>
# position=< 32640,  21752> velocity=<-3, -2>
#
# Initial position X: 32640
# Initial position Y: 21752
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32637,21750>
# position=<-53872,  32562> velocity=< 5, -3>
#
# Initial position X: -53872
# Initial position Y: 32562
# Velocity X:  5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-53867,32559>
# position=< 21829,  32562> velocity=<-2, -3>
#
# Initial position X: 21829
# Initial position Y: 32562
# Velocity X: -2
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <21827,32559>
# position=< 21851,  21752> velocity=<-2, -2>
#
# Initial position X: 21851
# Initial position Y: 21752
# Velocity X: -2
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <21849,21750>
# position=<-43057,  10936> velocity=< 4, -1>
#
# Initial position X: -43057
# Initial position Y: 10936
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43053,10935>
# position=<-10588, -32308> velocity=< 1,  3>
#
# Initial position X: -10588
# Initial position Y: -32308
# Velocity X:  1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-10587,-32305>
# position=< 21838,  10940> velocity=<-2, -1>
#
# Initial position X: 21838
# Initial position Y: 10940
# Velocity X: -2
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <21836,10939>
# position=<-21399, -10690> velocity=< 2,  1>
#
# Initial position X: -21399
# Initial position Y: -10690
# Velocity X:  2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-21397,-10689>
# position=< 54277, -32311> velocity=<-5,  3>
#
# Initial position X: 54277
# Initial position Y: -32311
# Velocity X: -5
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <54272,-32308>
# position=<-32198, -32312> velocity=< 3,  3>
#
# Initial position X: -32198
# Initial position Y: -32312
# Velocity X:  3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-32195,-32309>
# position=<-10599, -32315> velocity=< 1,  3>
#
# Initial position X: -10599
# Initial position Y: -32315
# Velocity X:  1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-10598,-32312>
# position=< 54285,  10945> velocity=<-5, -1>
#
# Initial position X: 54285
# Initial position Y: 10945
# Velocity X: -5
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <54280,10944>
# position=< 32641,  54188> velocity=<-3, -5>
#
# Initial position X: 32641
# Initial position Y: 54188
# Velocity X: -3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <32638,54183>
# position=< 11043,  21752> velocity=<-1, -2>
#
# Initial position X: 11043
# Initial position Y: 21752
# Velocity X: -1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <11042,21750>
# position=<-43059,  32564> velocity=< 4, -3>
#
# Initial position X: -43059
# Initial position Y: 32564
# Velocity X:  4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-43055,32561>
# position=<-43055, -32316> velocity=< 4,  3>
#
# Initial position X: -43055
# Initial position Y: -32316
# Velocity X:  4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-43051,-32313>
# position=<-53831,  43384> velocity=< 5, -4>
#
# Initial position X: -53831
# Initial position Y: 43384
# Velocity X:  5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-53826,43380>
# position=< 43469, -21496> velocity=<-4,  2>
#
# Initial position X: 43469
# Initial position Y: -21496
# Velocity X: -4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <43465,-21494>
# position=< 43482, -21496> velocity=<-4,  2>
#
# Initial position X: 43482
# Initial position Y: -21496
# Velocity X: -4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <43478,-21494>
# position=< 54295, -21500> velocity=<-5,  2>
#
# Initial position X: 54295
# Initial position Y: -21500
# Velocity X: -5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <54290,-21498>
# position=< 11050,  10941> velocity=<-1, -1>
#
# Initial position X: 11050
# Initial position Y: 10941
# Velocity X: -1
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <11049,10940>
# position=<-21430, -53937> velocity=< 2,  5>
#
# Initial position X: -21430
# Initial position Y: -53937
# Velocity X:  2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-21428,-53932>
# position=< 32656, -21502> velocity=<-3,  2>
#
# Initial position X: 32656
# Initial position Y: -21502
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32653,-21500>
# position=<-21401, -32311> velocity=< 2,  3>
#
# Initial position X: -21401
# Initial position Y: -32311
# Velocity X:  2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-21399,-32308>
# position=<-43022, -10684> velocity=< 4,  1>
#
# Initial position X: -43022
# Initial position Y: -10684
# Velocity X:  4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-43018,-10683>
# position=<-43063,  43384> velocity=< 4, -4>
#
# Initial position X: -43063
# Initial position Y: 43384
# Velocity X:  4
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-43059,43380>
# position=<-53848, -53936> velocity=< 5,  5>
#
# Initial position X: -53848
# Initial position Y: -53936
# Velocity X:  5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-53843,-53931>
# position=<-32214,  54191> velocity=< 3, -5>
#
# Initial position X: -32214
# Initial position Y: 54191
# Velocity X:  3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-32211,54186>
# position=<-10576, -43128> velocity=< 1,  4>
#
# Initial position X: -10576
# Initial position Y: -43128
# Velocity X:  1
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-10575,-43124>
# position=< 54284, -53933> velocity=<-5,  5>
#
# Initial position X: 54284
# Initial position Y: -53933
# Velocity X: -5
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <54279,-53928>
# position=<-32246,  54196> velocity=< 3, -5>
#
# Initial position X: -32246
# Initial position Y: 54196
# Velocity X:  3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-32243,54191>
# position=<-21420, -32308> velocity=< 2,  3>
#
# Initial position X: -21420
# Initial position Y: -32308
# Velocity X:  2
# Velocity Y:   3
# ...
# position=< 54306,  32564> velocity=<-5, -3>
#
# Initial position X: 54306
# Initial position Y: 32564
# Velocity X: -5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <54301,32561>
# position=<-32242,  43381> velocity=< 3, -4>
#
# Initial position X: -32242
# Initial position Y: 43381
# Velocity X:  3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-32239,43377>
# position=< 21819, -53939> velocity=<-2,  5>
#
# Initial position X: 21819
# Initial position Y: -53939
# Velocity X: -2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <21817,-53934>
# position=<-43023, -43124> velocity=< 4,  4>
#
# Initial position X: -43023
# Initial position Y: -43124
# Velocity X:  4
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-43019,-43120>
# position=< 43440,  54192> velocity=<-4, -5>
#
# Initial position X: 43440
# Initial position Y: 54192
# Velocity X: -4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <43436,54187>
# position=< 21862, -10681> velocity=<-2,  1>
#
# Initial position X: 21862
# Initial position Y: -10681
# Velocity X: -2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <21860,-10680>
# position=<-21416, -32310> velocity=< 2,  3>
#
# Initial position X: -21416
# Initial position Y: -32310
# Velocity X:  2
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-21414,-32307>
# position=< 54250, -21501> velocity=<-5,  2>
#
# Initial position X: 54250
# Initial position Y: -21501
# Velocity X: -5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <54245,-21499>
# position=< 54260,  54188> velocity=<-5, -5>
#
# Initial position X: 54260
# Initial position Y: 54188
# Velocity X: -5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <54255,54183>
# position=< 54261, -32312> velocity=<-5,  3>
#
# Initial position X: 54261
# Initial position Y: -32312
# Velocity X: -5
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <54256,-32309>
# position=< 43480,  21754> velocity=<-4, -2>
#
# Initial position X: 43480
# Initial position Y: 21754
# Velocity X: -4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <43476,21752>
# position=< 54250,  54188> velocity=<-5, -5>
#
# Initial position X: 54250
# Initial position Y: 54188
# Velocity X: -5
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <54245,54183>
# position=<-43051,  10941> velocity=< 4, -1>
#
# Initial position X: -43051
# Initial position Y: 10941
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43047,10940>
# position=<-21401,  43377> velocity=< 2, -4>
#
# Initial position X: -21401
# Initial position Y: 43377
# Velocity X:  2
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-21399,43373>
# position=< 43441, -53938> velocity=<-4,  5>
#
# Initial position X: 43441
# Initial position Y: -53938
# Velocity X: -4
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <43437,-53933>
# position=< 32648,  43375> velocity=<-3, -4>
#
# Initial position X: 32648
# Initial position Y: 43375
# Velocity X: -3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <32645,43371>
# position=< 54299, -10681> velocity=<-5,  1>
#
# Initial position X: 54299
# Initial position Y: -10681
# Velocity X: -5
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <54294,-10680>
# position=< 43477, -10685> velocity=<-4,  1>
#
# Initial position X: 43477
# Initial position Y: -10685
# Velocity X: -4
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <43473,-10684>
# position=<-43051,  54190> velocity=< 4, -5>
#
# Initial position X: -43051
# Initial position Y: 54190
# Velocity X:  4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-43047,54185>
# position=<-43035,  54190> velocity=< 4, -5>
#
# Initial position X: -43035
# Initial position Y: 54190
# Velocity X:  4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-43031,54185>
# position=<-32246,  32567> velocity=< 3, -3>
#
# Initial position X: -32246
# Initial position Y: 32567
# Velocity X:  3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-32243,32564>
# position=< 54262,  43382> velocity=<-5, -4>
#
# Initial position X: 54262
# Initial position Y: 43382
# Velocity X: -5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <54257,43378>
# position=<-53864,  32563> velocity=< 5, -3>
#
# Initial position X: -53864
# Initial position Y: 32563
# Velocity X:  5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-53859,32560>
# position=<-43064, -32307> velocity=< 4,  3>
#
# Initial position X: -43064
# Initial position Y: -32307
# Velocity X:  4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-43060,-32304>
# position=< 32676, -21501> velocity=<-3,  2>
#
# Initial position X: 32676
# Initial position Y: -21501
# Velocity X: -3
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <32673,-21499>
# position=<-21414,  43380> velocity=< 2, -4>
#
# Initial position X: -21414
# Initial position Y: 43380
# Velocity X:  2
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-21412,43376>
# position=<-21396,  54193> velocity=< 2, -5>
#
# Initial position X: -21396
# Initial position Y: 54193
# Velocity X:  2
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-21394,54188>
# position=< 32626,  10945> velocity=<-3, -1>
#
# Initial position X: 32626
# Initial position Y: 10945
# Velocity X: -3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <32623,10944>
# position=<-32202, -32311> velocity=< 3,  3>
#
# Initial position X: -32202
# Initial position Y: -32311
# Velocity X:  3
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-32199,-32308>
# position=<-43042, -53935> velocity=< 4,  5>
#
# Initial position X: -43042
# Initial position Y: -53935
# Velocity X:  4
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-43038,-53930>
# position=<-21433, -53940> velocity=< 2,  5>
#
# Initial position X: -21433
# Initial position Y: -53940
# Velocity X:  2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-21431,-53935>
# position=<-21425,  32566> velocity=< 2, -3>
#
# Initial position X: -21425
# Initial position Y: 32566
# Velocity X:  2
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-21423,32563>
# position=<-53855,  32568> velocity=< 5, -3>
#
# Initial position X: -53855
# Initial position Y: 32568
# Velocity X:  5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-53850,32565>
# position=< 21811, -43128> velocity=<-2,  4>
#
# Initial position X: 21811
# Initial position Y: -43128
# Velocity X: -2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <21809,-43124>
# position=<-21398, -21503> velocity=< 2,  2>
#
# Initial position X: -21398
# Initial position Y: -21503
# Velocity X:  2
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-21396,-21501>
# position=<-32241,  43384> velocity=< 3, -4>
#
# Initial position X: -32241
# Initial position Y: 43384
# Velocity X:  3
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-32238,43380>
# position=< 32680, -10684> velocity=<-3,  1>
#
# Initial position X: 32680
# Initial position Y: -10684
# Velocity X: -3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <32677,-10683>
# position=< 43477,  54195> velocity=<-4, -5>
#
# Initial position X: 43477
# Initial position Y: 54195
# Velocity X: -4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <43473,54190>
# position=< 32642,  32571> velocity=<-3, -3>
#
# Initial position X: 32642
# Initial position Y: 32571
# Velocity X: -3
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <32639,32568>
# position=<-32218, -43120> velocity=< 3,  4>
#
# Initial position X: -32218
# Initial position Y: -43120
# Velocity X:  3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-32215,-43116>
# position=< 11027,  54196> velocity=<-1, -5>
#
# Initial position X: 11027
# Initial position Y: 54196
# Velocity X: -1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <11026,54191>
# position=<-10617,  54193> velocity=< 1, -5>
#
# Initial position X: -10617
# Initial position Y: 54193
# Velocity X:  1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <-10616,54188>
# position=< 54262,  32562> velocity=<-5, -3>
#
# Initial position X: 54262
# Initial position Y: 32562
# Velocity X: -5
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <54257,32559>
# position=< 11006,  21754> velocity=<-1, -2>
#
# Initial position X: 11006
# Initial position Y: 21754
# Velocity X: -1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <11005,21752>
# position=< 43470,  21758> velocity=<-4, -2>
#
# Initial position X: 43470
# Initial position Y: 21758
# Velocity X: -4
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <43466,21756>
# position=< 54306,  43383> velocity=<-5, -4>
#
# Initial position X: 54306
# Initial position Y: 43383
# Velocity X: -5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <54301,43379>
# position=< 43469, -32315> velocity=<-4,  3>
#
# Initial position X: 43469
# Initial position Y: -32315
# Velocity X: -4
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <43465,-32312>
# position=< 21819, -53939> velocity=<-2,  5>
#
# Initial position X: 21819
# Initial position Y: -53939
# Velocity X: -2
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <21817,-53934>
# position=< 43446,  54188> velocity=<-4, -5>
#
# Initial position X: 43446
# Initial position Y: 54188
# Velocity X: -4
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <43442,54183>
# position=< 32669, -10681> velocity=<-3,  1>
#
# Initial position X: 32669
# Initial position Y: -10681
# Velocity X: -3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <32666,-10680>
# position=<-53879, -21503> velocity=< 5,  2>
#
# Initial position X: -53879
# Initial position Y: -21503
# Velocity X:  5
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-53874,-21501>
# position=< 32637,  54189> velocity=<-3, -5>
#
# Initial position X: 32637
# Initial position Y: 54189
# Velocity X: -3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <32634,54184>
# position=< 11030,  54193> velocity=<-1, -5>
#
# Initial position X: 11030
# Initial position Y: 54193
# Velocity X: -1
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <11029,54188>
# position=<-10612, -53939> velocity=< 1,  5>
#
# Initial position X: -10612
# Initial position Y: -53939
# Velocity X:  1
# Velocity Y:   5
# New coordinates due change in position after 1 seconds: <-10611,-53934>
# position=<-32219,  10945> velocity=< 3, -1>
#
# Initial position X: -32219
# Initial position Y: 10945
# Velocity X:  3
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-32216,10944>
# position=<-21429, -10683> velocity=< 2,  1>
#
# Initial position X: -21429
# Initial position Y: -10683
# Velocity X:  2
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-21427,-10682>
# position=< 54271, -43128> velocity=<-5,  4>
#
# Initial position X: 54271
# Initial position Y: -43128
# Velocity X: -5
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <54266,-43124>
# position=<-43063,  10936> velocity=< 4, -1>
#
# Initial position X: -43063
# Initial position Y: 10936
# Velocity X:  4
# Velocity Y:  -1
# New coordinates due change in position after 1 seconds: <-43059,10935>
# position=< 32649, -43123> velocity=<-3,  4>
#
# Initial position X: 32649
# Initial position Y: -43123
# Velocity X: -3
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <32646,-43119>
# position=<-53855, -43122> velocity=< 5,  4>
#
# Initial position X: -53855
# Initial position Y: -43122
# Velocity X:  5
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-53850,-43118>
# position=< 43477,  43381> velocity=<-4, -4>
#
# Initial position X: 43477
# Initial position Y: 43381
# Velocity X: -4
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <43473,43377>
# position=<-10602, -32312> velocity=< 1,  3>
#
# Initial position X: -10602
# Initial position Y: -32312
# Velocity X:  1
# Velocity Y:   3
# New coordinates due change in position after 1 seconds: <-10601,-32309>
# position=<-21382, -43120> velocity=< 2,  4>
#
# Initial position X: -21382
# Initial position Y: -43120
# Velocity X:  2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-21380,-43116>
# position=< 11023,  21756> velocity=<-1, -2>
#
# Initial position X: 11023
# Initial position Y: 21756
# Velocity X: -1
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <11022,21754>
# position=<-21401, -43121> velocity=< 2,  4>
#
# Initial position X: -21401
# Initial position Y: -43121
# Velocity X:  2
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <-21399,-43117>
# position=< 43478,  32567> velocity=<-4, -3>
#
# Initial position X: 43478
# Initial position Y: 32567
# Velocity X: -4
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <43474,32564>
# position=<-43033,  43384> velocity=< 4, -4>
#
# Initial position X: -43033
# Initial position Y: 43384
# Velocity X:  4
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-43029,43380>
# position=<-10576,  32568> velocity=< 1, -3>
#
# Initial position X: -10576
# Initial position Y: 32568
# Velocity X:  1
# Velocity Y:  -3
# New coordinates due change in position after 1 seconds: <-10575,32565>
# position=< 32635,  54188> velocity=<-3, -5>
#
# Initial position X: 32635
# Initial position Y: 54188
# Velocity X: -3
# Velocity Y:  -5
# New coordinates due change in position after 1 seconds: <32632,54183>
# position=<-53844,  43384> velocity=< 5, -4>
#
# Initial position X: -53844
# Initial position Y: 43384
# Velocity X:  5
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-53839,43380>
# position=<-32209, -10682> velocity=< 3,  1>
#
# Initial position X: -32209
# Initial position Y: -10682
# Velocity X:  3
# Velocity Y:   1
# New coordinates due change in position after 1 seconds: <-32206,-10681>
# position=< 21822, -21503> velocity=<-2,  2>
#
# Initial position X: 21822
# Initial position Y: -21503
# Velocity X: -2
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <21820,-21501>
# position=<-10580,  43383> velocity=< 1, -4>
#
# Initial position X: -10580
# Initial position Y: 43383
# Velocity X:  1
# Velocity Y:  -4
# New coordinates due change in position after 1 seconds: <-10579,43379>
# position=< 32652,  21751> velocity=<-3, -2>
#
# Initial position X: 32652
# Initial position Y: 21751
# Velocity X: -3
# Velocity Y:  -2
# New coordinates due change in position after 1 seconds: <32649,21749>
# position=< 54258, -43127> velocity=<-5,  4>
#
# Initial position X: 54258
# Initial position Y: -43127
# Velocity X: -5
# Velocity Y:   4
# New coordinates due change in position after 1 seconds: <54253,-43123>
# position=<-43067, -21498> velocity=< 4,  2>
#
# Initial position X: -43067
# Initial position Y: -21498
# Velocity X:  4
# Velocity Y:   2
# New coordinates due change in position after 1 seconds: <-43063,-21496>
# position=<-21400,  54189> velocity=< 2, -5>
# Initial position X: -21400
# Initial position Y: 54189
# Velocity X:  2
# Velocity Y:  -
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-d08660afcf81> in <module>()
#      46 #sec += 1
#      47
# ---> 48 yet_another_position_shift()
#
# <ipython-input-81-d08660afcf81> in yet_another_position_shift()
#      41
#      42                 newCoordx=sec*int(posX)+int(movX)
# ---> 43                 newCoordy=sec*int(posY1)+int(movY)
#      44                 print('New coordinates due change in position after '+str(sec)+' seconds: <'+str(newCoordx)+','+str(newCoordy)+'>')
#      45
#
# ValueError: invalid literal for int() with base 10: ' -'
